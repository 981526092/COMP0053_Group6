# %% [markdown]
# # Load libraries

# %%
import numpy as np
from visualisation_utils import plot_target,plot_confusion_matrix,plot_model_scores
from data_utils import get_filenames_without_extension,load_data,load_raw_data

# %%
train_participant_num = get_filenames_without_extension("../CoordinateData/train")
valid_participant_num = get_filenames_without_extension("../CoordinateData/validation")

# %% [markdown]
# # Participant Number for Train and Validation Datasets

# %%
len(train_participant_num),len(valid_participant_num)
# Out:
# (23, 12)

# %%
train_raw_data = load_raw_data(train_participant_num,"train")
valid_raw_data = load_raw_data(valid_participant_num,"validation")

# %%
X_train_data,Y_train_data = load_data(train_participant_num,"train",downsampling=False)
X_valid_data,Y_valid_data = load_data(valid_participant_num,"validation")

# %%
train_raw_data.shape
# Out:
# (356107, 78)

# %%
X_train_data.shape
# Out:
# (6555, 180, 70)

# %%
plot_target(Y_train_data[:,1])
