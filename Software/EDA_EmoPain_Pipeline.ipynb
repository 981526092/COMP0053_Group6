# %% [markdown]
# # Load libraries

# %%
import numpy as np
from visualisation_utils import plot_target,plot_confusion_matrix,plot_model_scores
from data_utils import get_filenames_without_extension,load_data,load_raw_data
from matplotlib import pyplot as plt

# %% [markdown]
# # Get Participant Number for Train and Validation Datasets

# %%
train_participant_num = get_filenames_without_extension("../CoordinateData/train")
valid_participant_num = get_filenames_without_extension("../CoordinateData/validation")

# %%
len(train_participant_num),len(valid_participant_num)
# Out:
# (23, 12)

# %% [markdown]
# # Load Raw Train Data from AllData route

# %%
train_raw_data = load_raw_data(train_participant_num,"train",data_path='../AllData/')
valid_raw_data = load_raw_data(valid_participant_num,"validation",data_path='../AllData/')

# %%
train_raw_data.shape
# Out:
# (356107, 104)

# %% [markdown]
# # Load Coordinate Train Data (without Downsampling)

# %%
X_train_data_ND,Y_train_data_ND = load_data(train_participant_num,"train",downsampling=False)

# %%
X_train_data_ND.shape
# Out:
# (6555, 180, 70)

# %% [markdown]
# # Load Coordinate Train Data (with Downsampling)

# %%
X_train_data_WD,Y_train_data_WD = load_data(train_participant_num,"train",downsampling=True)
# Out:
# P492D is selected to be used for training (downsampling)
# P191D is selected to be used for training (downsampling)
# P113D is selected to be used for training (downsampling)
# P890N is selected to be used for training (downsampling)
# P299D is selected to be used for training (downsampling)
# P921N is selected to be used for training (downsampling)
# C709N is not selected to be used for training (downsampling)
# C382D is not selected to be used for training (downsampling)
# P699D is selected to be used for training (downsampling)
# P531N is selected to be used for training (downsampling)
# P336D is selected to be used for training (downsampling)
# P699N is selected to be used for training (downsampling)
# P300D is selected to be used for training (downsampling)
# C56D is not selected to be used for training (downsampling)
# C788N is not selected to be used for training (downsampling)
# C544D is not selected to be used for training (downsampling)
# ...

# %%
X_train_data_WD.shape
# Out:
# (5012, 180, 70)

# %% [markdown]
# # Target Distribution Plot without downsampling

# %%
plot_target(Y_train_data_ND[:,1])

# %% [markdown]
# # Target Distribution Plot with downsampling

# %%
plot_target(Y_train_data_WD[:,1])

# %% [markdown]
# # Plot the first sample of the dataset

# %%
plt.figure(figsize=(10, 5))
plt.plot(X_train_data_WD[0].T)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Wave plot for sample 0')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_raw_data[0].T)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Wave plot for sample 0')
plt.show()
